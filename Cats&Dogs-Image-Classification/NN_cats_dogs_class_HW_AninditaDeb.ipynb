# %% [markdown]
# ## Cats/Dogs Keras Standard NN  ##
# ## Constructing X and Y for Keras ##
# Use validation_split to monitor validation and overfit
# CPE 4903 HW Starter Jupyter File
# Instructions - see assignment in D2L

# %%
import numpy as np 

import os  # avoid kernal die
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

import matplotlib.pyplot as plt
import os, cv2, itertools # cv2 -- OpenCV
print('done')
# Out:
# done

# %%
import keras
from keras.layers import Input, Dense, Dropout
from keras.models import Model, Sequential
import tensorflow as tf
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
print('done')
# Out:
# done

# %%
# np.savez_compressed('cats_dogs', X_train, X_test, y_train, y_test )
# X (nx x m), Y (1xm)
data = np.load('cats_equal_1.npz') # Cats = 1 output, dogs = 0
print('done')
# Out:
# done

# %%
data.files
# Out:
# ['arr_0', 'arr_1', 'arr_2', 'arr_3']

# %% [markdown]
# ### Your code here to extract your training and test data matrices from "data".
# ### Be sure to scale your data by dividing by 255 and reshape to get proper shapes of X and Y
# ![image.png](attachment:38877e6f-99ad-4461-9827-02530efda3e0.png)

# %%
# Your code here
# Correct directory path
X_train = data['arr_0']
X_test = data['arr_1']
Y_train = data['arr_2']
Y_test = data['arr_3']

X_train = X_train
X_test = X_test
Y_train = Y_train.T
Y_test = Y_test.T

X_train = X_train/255
X_test = X_test/255

print(f'shape of X_train {X_train.shape}')
print(f'shape of X_test {X_test.shape}')
print(f'shape of Y_train {Y_train.shape}')
print(f'shape of Y_test {Y_test.shape}')
# Out:
# shape of X_train (20000, 12288)
# shape of X_test (5000, 12288)
# shape of Y_train (20000, 1)
# shape of Y_test (5000, 1)

# %%
ROWS = 64
COLS = 64
CHANNELS = 3
def read_image(file_path):
  img = cv2.imread(file_path, cv2.IMREAD_COLOR)
  return cv2.resize(img, (ROWS, COLS),interpolation=cv2.INTER_CUBIC)

# %%
X_train[:1].shape
# Out:
# (1, 12288)

# %%
nx = X_train.shape[1]
X_train.shape
# Out:
# (20000, 12288)

# %%
nx
# Out:
# 12288

# %% [markdown]
# ### Your Keras code next
# Ending with these two lines
# ![image.png](attachment:06c67e26-893f-4370-b3c6-03e66227f9ab.png)
#
# Be sure to plot the loss and accuracy of both training and validation
# ![image.png](attachment:11a9f155-5ce4-4dc1-83d3-959d8a12ef82.png)
# ![image.png](attachment:33381c88-cae3-4e28-b98e-51ec2250faca.png)

# %%
# Your Keras code here

# %%
model = Sequential()
model.add(Dense(units=10,activation='relu',input_dim=nx))
model.add(Dropout(0.2))
model.add(Dense(units=10,activation='relu'))
model.add(Dropout(0.2))
#model.add(Dense(units=5,activation='relu'))
model.add(Dense(units=1,activation='sigmoid'))
opt=keras.optimizers.SGD(learning_rate = 0.01)
#opt=keras.optimizers.Adam()
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
print(model.summary())
history = model.fit(X_train,Y_train,epochs=10,batch_size=200,validation_split = .2, verbose=1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 10)                122890
#
#  dropout_2 (Dropout)         (None, 10)                0
#
#  dense_4 (Dense)             (None, 10)                110
#
#  dropout_3 (Dropout)         (None, 10)                0
#
#  dense_5 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 123,011
# Trainable params: 123,011
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 80/80 [==============================] - 15s 135ms/step - loss: 0.6929 - accuracy: 0.5192 - val_loss: 0.6879 - val_accuracy: 0.5440
# Epoch 2/10
# 80/80 [==============================] - 4s 56ms/step - loss: 0.6880 - accuracy: 0.5413 - val_loss: 0.6843 - val_accuracy: 0.5645
# Epoch 3/10
# 80/80 [==============================] - 3s 40ms/step - loss: 0.6837 - accuracy: 0.5538 - val_loss: 0.6798 - val_accuracy: 0.5825
# Epoch 4/10
# 80/80 [==============================] - 4s 45ms/step - loss: 0.6796 - accuracy: 0.5612 - val_loss: 0.6736 - val_accuracy: 0.6083
# Epoch 5/10
# 80/80 [==============================] - 4s 53ms/step - loss: 0.6761 - accuracy: 0.5734 - val_loss: 0.6711 - val_accuracy: 0.5982
# Epoch 6/10
# 80/80 [==============================] - 5s 59ms/step - loss: 0.6723 - accuracy: 0.5778 - val_loss: 0.6673 - val_accuracy: 0.5993
# Epoch 7/10
# 80/80 [==============================] - 2s 29ms/step - loss: 0.6690 - accuracy: 0.5844 - val_loss: 0.6628 - val_accuracy: 0.6072
# Epoch 8/10
# 80/80 [==============================] - 3s 40ms/step - loss: 0.6670 - accuracy: 0.5926 - val_loss: 0.6609 - val_accuracy: 0.6122
# Epoch 9/10
# 80/80 [==============================] - 3s 41ms/step - loss: 0.6664 - accuracy: 0.5910 - val_loss: 0.6634 - val_accuracy: 0.6093
# Epoch 10/10
# 80/80 [==============================] - 3s 41ms/step - loss: 0.6638 - accuracy: 0.5942 - val_loss: 0.6571 - val_accuracy: 0.6202

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Test Cases
# ### Run code below to see if your model can recognize cat and dog not-seen-before images

# %%
# Evaluate the model on the training data using `evaluate`
print('Evaluate on train data')
Yhat = model.predict(X_train)  
acc = np.mean(np.rint(Yhat) == Y_train)  
print('The train accuracy rate is: ', acc * 100)
# Out:
# Evaluate on train data
# 625/625 [==============================] - 36s 57ms/step
# The train accuracy rate is:  62.2

# %%
# Evaluate the model on the training data using `evaluate`
print('Evaluate on test data')
Yhat_test = model.predict(X_test)
acc = np.mean(np.rint(Yhat_test) == Y_test) # good trick to calculate % correct from binary output comparison
print('The test accuracy rate is: ', acc * 100)
# Out:
# Evaluate on test data
# 157/157 [==============================] - 12s 65ms/step
# The test accuracy rate is:  61.44

# %%
file = "cat2.jpg"
test_image = read_image(file)
X_img = test_image.reshape(1, ROWS*COLS*CHANNELS)/255
A = model.predict(X_img)
if A>.5:
    print('Prediction: CAT with probability {}%'. format(A*100))
else:
    print('Prediction: DOG with probability {}%'. format(100-A*100))
plt.imshow(test_image)
# Out:
# 1/1 [==============================] - 0s 195ms/step
# Prediction: DOG with probability [[56.15198]]%

# %%
file = "dog2.jpg"
test_image = read_image(file)
X_img = test_image.reshape(1, ROWS*COLS*CHANNELS)/255
A = model.predict(X_img)
if A>.5:
    print('Prediction: CAT with probability {}%'. format(A*100))
else:
    print('Prediction: DOG with probability {}%'. format(100-A*100))
plt.imshow(test_image)
# Out:
# 1/1 [==============================] - 0s 118ms/step
# Prediction: DOG with probability [[65.337555]]%

# %%
# Configuring X asnd Y shapes for CNN
X_train2 = X_train.reshape(X_train.shape[0], 64,64, 3)   #samples, w, h, channels
X_test2 = X_test.reshape(X_test.shape[0], 64,64,3)
Y_train2 = Y_train.reshape(-1,1)
Y_test2 = Y_test.reshape(-1,1)

print('Shape of x_train2 is {}'.format(X_train2.shape))
print('Shape of x_test2 is {}'.format(X_test2.shape))
print('Shape of y_train is {}'.format(Y_train2.shape))
print('Shape of y_test is {}'.format(Y_test2.shape))
# Out:
# Shape of x_train2 is (20000, 64, 64, 3)
# Shape of x_test2 is (5000, 64, 64, 3)
# Shape of y_train is (20000, 1)
# Shape of y_test is (5000, 1)

# %%
model2 = Sequential()


model2.add(Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)))
model2.add(MaxPooling2D((2, 2)))
model2.add(Conv2D(64, (3, 3), activation='relu'))
model2.add(MaxPooling2D((2, 2)))
model2.add(Conv2D(128, (3, 3), activation='relu'))
model2.add(MaxPooling2D((2, 2)))


model2.add(Flatten())
model2.add(Dense(128, activation='relu'))
model2.add(Dropout(0.5))  
model2.add(Dense(1, activation='sigmoid'))  


model2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

print(model2.summary())
history2 = model2.fit(X_train2, Y_train2, epochs=10, batch_size=128, validation_data=(X_test2, Y_test2))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 62, 62, 32)        896
#
#  max_pooling2d_3 (MaxPooling  (None, 31, 31, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 29, 29, 64)        18496
#
#  max_pooling2d_4 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 128)       73856
#
#  max_pooling2d_5 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 4608)              0
#
#  dense_8 (Dense)             (None, 128)               589952
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_9 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 683,329
# Trainable params: 683,329
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 157/157 [==============================] - 55s 336ms/step - loss: 0.6163 - accuracy: 0.6449 - val_loss: 0.5348 - val_accuracy: 0.7390
# Epoch 2/10
# 157/157 [==============================] - 47s 301ms/step - loss: 0.5021 - accuracy: 0.7602 - val_loss: 0.5083 - val_accuracy: 0.7466
# Epoch 3/10
# 157/157 [==============================] - 44s 280ms/step - loss: 0.4399 - accuracy: 0.7983 - val_loss: 0.4015 - val_accuracy: 0.8158
# Epoch 4/10
# 157/157 [==============================] - 46s 295ms/step - loss: 0.3938 - accuracy: 0.8210 - val_loss: 0.3869 - val_accuracy: 0.8218
# Epoch 5/10
# 157/157 [==============================] - 44s 283ms/step - loss: 0.3651 - accuracy: 0.8383 - val_loss: 0.3612 - val_accuracy: 0.8378
# Epoch 6/10
# 157/157 [==============================] - 45s 288ms/step - loss: 0.3270 - accuracy: 0.8583 - val_loss: 0.3484 - val_accuracy: 0.8470
# Epoch 7/10
# 157/157 [==============================] - 48s 305ms/step - loss: 0.2892 - accuracy: 0.8762 - val_loss: 0.4590 - val_accuracy: 0.7912
# Epoch 8/10
# 157/157 [==============================] - 44s 282ms/step - loss: 0.2608 - accuracy: 0.8896 - val_loss: 0.3478 - val_accuracy: 0.8510
# Epoch 9/10
# 157/157 [==============================] - 45s 288ms/step - loss: 0.2277 - accuracy: 0.9053 - val_loss: 0.3694 - val_accuracy: 0.8540
# Epoch 10/10
# 157/157 [==============================] - 48s 304ms/step - loss: 0.2030 - accuracy: 0.9184 - val_loss: 0.3821 - val_accuracy: 0.8396

# %%
# Evaluate the model on the training data using `evaluate`
print('Evaluate on train data')
Yhat = model2.predict(X_train2)
acc = np.mean(np.rint(Yhat) == Y_train2) # good trick to calculate % correct from binary output compaison
print('The train accuracy rate is: ', acc * 100)
# Out:
# Evaluate on train data
# 625/625 [==============================] - 17s 24ms/step
# The train accuracy rate is:  92.735

# %%
# Evaluate the model on the training data using `evaluate`
print('Evaluate on test data')
Yhat_test = model2.predict(X_test2)
acc = np.mean(np.rint(Yhat_test) == Y_test2) # good trick to calculate % correct from binary output compaison
print('The test accuracy rate is: ', acc * 100)
# Out:
# Evaluate on test data
# 157/157 [==============================] - 4s 26ms/step
# The test accuracy rate is:  83.96000000000001

# %%
acc_cnn = history2.history['accuracy']
val_acc_cnn = history2.history['val_accuracy']
acc_nn = history.history['accuracy']  
val_acc_nn = history.history['val_accuracy']  

epochs = range(1, len(acc_cnn) + 1)


plt.plot(epochs, acc_cnn, 'b', label='CNN Training accuracy')
plt.plot(epochs, val_acc_cnn, 'r', label='CNN Validation accuracy')
plt.plot(epochs, acc_nn, 'b--', label='NN Training accuracy')  
plt.plot(epochs, val_acc_nn, 'r--', label='NN Validation accuracy') 
plt.title('Training and validation accuracy comparison')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
